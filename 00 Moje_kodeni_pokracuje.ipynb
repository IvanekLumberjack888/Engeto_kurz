# %%
'''Takže tady píši několik prvních python scriptů'''
print("Ahoj světe. Já jsem Ivoš 🧙‍♂️ ")
# Out:
# Ahoj světe. Já jsem Ivoš 🧙‍♂️

# %%
# Aritmetické oprace:
print(1+2+3+2560)
# Out:
# 2566

# %%
print(10 // 3) #celočíselné dělení
print(11 * 11)
print(11 ** 2) #na druhou :-)
#modulo Pepo:
print(5 % 2)
print("ano, správně je to zbytek po dělení.")
print("---")
print("a docela se to využije potom ke zjištění jestli je číslo sudé nebo liché 🤣 ")
# Out:
# 3
# 121
# 121
# 1
# ano, správně je to zbytek po dělení.
# ---
# a docela se to využije potom ke zjištění jestli je číslo sudé nebo liché 🤣

# %%
# A co takhle float?
print(9 + 0.45)
print(type(9 + 0.45)) #nástupiště do Bradavic :-D
# Out:
# 9.45
# <class 'float'>

# %% [markdown]
# ![3-body-problem-1.jpg](data:image/jpeg;base64,...)Zatím to vypadá bez problému.

# %%
''' A teď to začne... Hierarchieeee
Pořadí	Operátor	Proces
1.	()	závorky
2.	**	umocňování
3.	*	násobení
4.	/	dělení
5.	+	sčítání
6.	-	odčítaní
'''
print(3 * (3 * 3)) #kde je medvěd..?
print(3 + 3 / (3 * 3)) #kde??
print(9 - (18 // 2)) #zmizel a je zmizelej
print(("d,e,v,e,t"))
print("Takže 3 x 3 je devět!")
print(9 * "👍")
# Out:
# 27
# 3.3333333333333335
# 0
# d,e,v,e,t
# Takže 3 x 3 je devět!
# 👍👍👍👍👍👍👍👍👍

# %%
#A nezapomenout na ty Apostrofy
print("Piš si Rock and Roll jako - Rock´n Roll")
# A pokud potřebuješ zapsat ještě jinak apostrof, tak to je takhle:
print("zpětné lomítko ")
# Out:
# Piš si Rock and Roll jako - Rock´n Roll
